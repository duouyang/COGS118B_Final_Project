# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import show_img as si
import pandas as pd 

data = pickle.load(open('data0.pickle', 'rb'))

# %% [markdown]
# ### We only use five classes

# %%
# speed limit - 0   ----> 0
# no passing - 9    ----> 1
# yield - 13        ----> 2
# stop - 14         ----> 3  
# pedestrian - 27   ----> 4

# load data

x_train = data['x_train']
y_train = data['y_train']
x_data = []
y_data = []

for i in range(len(y_train)):
    if y_train[i] == 0:
        x_data.append(x_train[i])
        y_data.append(0)
    if y_train[i] == 9:
        x_data.append(x_train[i])
        y_data.append(1)
    if y_train[i] == 13:
        x_data.append(x_train[i])
        y_data.append(2)
    if y_train[i] == 14:
        x_data.append(x_train[i])
        y_data.append(3)
    if y_train[i] == 27:
        x_data.append(x_train[i])
        y_data.append(4)
x_data = np.asarray(x_data)
y_data = np.asarray(y_data)

# %%
#plt.imshow(x_greyscale[2],cmap='gray')

# reshape the data to a vector
x_data = x_data.reshape(10115, 3072)

# %%
num_test = 1000
x_test = x_data[0:num_test]
y_test = y_data[0:num_test]

x_train = x_data[num_test:-1]
y_train = y_data[num_test:-1]

# %%
def pred_label_fn(i, original):
    return original + '::' + meta[predictions[i]]

meta = {
    0:'speed limit 20',
    1:'no passing',
    2:'yield',
    3:'stop',
    4:'pedestrian'
}

# %%
# train classifer and make predictions on test data
nbrs = KNeighborsClassifier(n_neighbors=3, algorithm='brute').fit(x_train, y_train)
predictions = nbrs.predict(x_test)

# calculate accuracy and plot wrong predictions
total = 0
correct = 0
for i in range(len(predictions)):
    total += 1
    if predictions[i] == y_test[i]:
        correct += 1
        continue
    si.show_img(x_test, y_test, meta, i, label_fn=pred_label_fn)
print('The test accuracy is ', correct/total)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0278>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE02B0>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE05C0>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE02B0>
# no passing::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0518>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE02B0>
# yield::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0588>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE02B0>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0588>
# pedestrian::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# yield::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0550>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0550>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0518>
# stop::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0278>
# stop::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# stop::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0278>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# speed limit 20::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE05C0>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# pedestrian::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE05C0>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0518>
# stop::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE05F8>
# stop::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE0630>
# speed limit 20::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABE05F8>
# no passing::stop
# The test accuracy is  0.974

# %%
for i in range(0, len(predictions)):

    si.show_img(x_test, y_test, meta, i, label_fn=pred_label_fn)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCC50>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# ...
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC240>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC6A0>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# no passing::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# stop::stop
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCAC8>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# speed limit 20::speed limit 20
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCB00>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDCBA8>
# pedestrian::pedestrian
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# yield::yield
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC470>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC668>
# no passing::no passing
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FA7CABDC278>
# no passing::no passing
